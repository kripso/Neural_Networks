# %%
from tensorflow.keras.models import load_model
from tensorflow.keras import backend as K
import data_processing
import yaml

# %%
def get_config(key) -> int:
    with open('./conf/config.yaml') as file:
        file = yaml.load(file, Loader=yaml.FullLoader)

    return file[key]

# %%
paths = get_config('PATHS')

# %%
K.clear_session()

# %%
K.clear_session()
model = load_model(paths['MODEL_PATH'])
# Out:
# 2022-04-05 16:15:13.017783: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 268435456 exceeds 10% of free system memory.
# 2022-04-05 16:15:13.018889: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 268435456 exceeds 10% of free system memory.

# %%
i = 100
for filename in os.scandir(paths['BASE_PATH']+paths['TEST_SAMPLES']):
    if filename.is_file() and '.DS_Store' not in filename.path:
        sample_name = filename.path
        data_processing.evaluate_data(model, paths['BASE_PATH']+paths['TEST_CLASSES'], sample_name,)
        i -=1 
        if i<=0:
            break
# Out:
# 0.9957761
# 0.81476396
# 0.0027826314
# 0.99560994
# 0.053201713
# 0.002352586
# 0.99200106
# 0.9834062
# 0.0037277178
